# %%
import pandas as pd
import json

# %%
file_path = '2023/202300000'

# %%
df = pd.read_json(file_path)

# %%
f = open(file_path)
json_data = json.load(f)
f.close()

# %%
for key in json_data['abstracts-retrieval-response'].keys(): 
    print(json_data['abstracts-retrieval-response'][key])
# Out:
# {'ait:process-info': {'ait:status': {'@state': 'update', '@type': 'core', '@stage': 'S300'}, 'ait:date-delivered': {'@day': '13', '@timestamp': '2023-09-13T08:20:31.000031-04:00', '@year': '2023', '@month': '09'}, 'ait:date-sort': {'@day': '31', '@year': '2023', '@month': '12'}}, 'xocs:meta': {'xocs:funding-list': {'@pui-match': 'primary', '@has-funding-info': '1', 'xocs:funding': [{'xocs:funding-agency-matched-string': 'NSRF', 'xocs:funding-id': 'B05F640083'}, {'xocs:funding-agency-matched-string': 'Chulalongkorn University', 'xocs:funding-agency-acronym': 'CU', 'xocs:funding-agency': 'Chulalongkorn University', 'xocs:funding-agency-id': 'http://data.elsevier.com/vocabulary/SciValFunders/501100002873', 'xocs:funding-agency-country': 'http://sws.geonames.org/1605651/'}, {'xocs:funding-agency-matched-string': 'Thailand Science research and Innovation Fund', 'xocs:funding-agency-acronym': 'TSRI', 'xocs:funding-agency': 'Thailand Science Research and Innovation', 'xocs:funding-id': 'CU_
# ...

# %%
json_data['abstracts-retrieval-response']['item']
# Out:
# {'ait:process-info': {'ait:status': {'@state': 'update',
#    '@type': 'core',
#    '@stage': 'S300'},
#   'ait:date-delivered': {'@day': '13',
#    '@timestamp': '2023-09-13T08:20:31.000031-04:00',
#    '@year': '2023',
#    '@month': '09'},
#   'ait:date-sort': {'@day': '31', '@year': '2023', '@month': '12'}},
#  'xocs:meta': {'xocs:funding-list': {'@pui-match': 'primary',
#    '@has-funding-info': '1',
#    'xocs:funding': [{'xocs:funding-agency-matched-string': 'NSRF',
#      'xocs:funding-id': 'B05F640083'},
#     {'xocs:funding-agency-matched-string': 'Chulalongkorn University',
#      'xocs:funding-agency-acronym': 'CU',
#      'xocs:funding-agency': 'Chulalongkorn University',
#      'xocs:funding-agency-id': 'http://data.elsevier.com/vocabulary/SciValFunders/501100002873',
#      'xocs:funding-agency-country': 'http://sws.geonames.org/1605651/'},
#     {'xocs:funding-agency-matched-string': 'Thailand Science research and Innovation Fund',
# ...
